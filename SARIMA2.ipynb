# %% [markdown]
# #Libraries

# %%
# !pip install pmdarima

# %%
import pandas as pd
from pmdarima import auto_arima

# %% [markdown]
# # Data

# %%
df =   pd.read_csv("https://bit.ly/udemy_df",
              index_col = "Date",
              parse_dates = True).asfreq("D")
df.head()
# Out:
#             Udemy  Easter  Christmas
# Date
# 2016-01-01    311       0          0
# 2016-01-02    564       0          0
# 2016-01-03    517       0          0
# 2016-01-04    652       0          0
# 2016-01-05    756       0          0

# %%
#training and test set
training = df.iloc[:-31,:]
test = df.iloc[-31:, :]

# %% [markdown]
# # SARIMA Model

# %%
#SARIMA model
model = auto_arima(y = training.Udemy,
                   m = 7)

# %%
#Predictions
predictions = pd.Series(model.predict(n_periods = len(test)))
predictions.index = test.index
predictions[:5]
# Out:
# Date
# 2020-12-01    2453.354799
# 2020-12-02    2312.502544
# 2020-12-03    2301.727243
# 2020-12-04    2290.402417
# 2020-12-05    1876.607832
# Freq: D, dtype: float64

# %%
#Visualization
training['Udemy']['2020-01-01':].plot(figsize = (12,8), legend = True)
test['Udemy'].plot( legend = True)
predictions.plot(legend = True)
